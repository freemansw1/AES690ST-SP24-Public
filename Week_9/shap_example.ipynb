# %% [markdown]
# # SHAP

# %%
# %matplotlib inline

# %%
import tensorflow as tf
import numpy as np
import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
import pandas as pd
import copy

# %%
# !pip install shap

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# Let's load in our ASOS station dataset.

# %%
input_data = pd.read_csv("../Week_5/al_asos_jul_23_v2.csv")

# %%
input_data
# Out:
#       station             valid  tmpf   tmpc  dwpf   dwpc    relh    feel  \
# 0         HEY  2023-07-01 00:11  87.8  31.00  71.6  22.00   58.78   94.18
# 1         SXS  2023-07-01 00:12  87.8  31.00  71.6  22.00   58.78   94.18
# 2         HUA  2023-07-01 00:14  89.6  32.00  77.0  25.00   66.55  102.54
# 3         8A0  2023-07-01 00:15  86.0  30.00  73.4  23.00   66.15   93.45
# 4         4A6  2023-07-01 00:15   NaN    NaN   NaN    NaN     NaN     NaN
# ...       ...               ...   ...    ...   ...    ...     ...     ...
# 64232     EKY  2023-07-30 23:56  79.0  26.11  76.0  24.44   90.55   79.00
# 64233     79J  2023-07-30 23:56  76.0  24.44  73.0  22.78   90.44   76.00
# 64234     SXS  2023-07-30 23:56  73.4  23.00  73.4  23.00  100.00   73.40
# 64235     EUF  2023-07-30 23:58  79.0  26.11  75.0  23.89   87.58   79.00
# 64236     0J4  2023-07-30 23:58  78.0  25.56  72.0  22.22   81.82   78.00
#
#        sknt    mslp    p01m    p01i  gust skyc1   skyl1
# 0       0.0  1013.0  0.0000  0.0000   NaN   CLR     NaN
# 1       0.0  1013.6  0.0000  0.0000   NaN   CLR     NaN
# 2       5.0  1013.9  0.0000  0.0000   NaN   FEW  4700.0
# 3       0.0     NaN  0.0000  0.0000   NaN   CLR     NaN
# 4       NaN     NaN  0.0000  0.0000   NaN   NaN     NaN
# ...     ...     ...     ...     ...   ...   ...     ...
# 64232   0.0  1001.8  0.0000  0.0000   NaN   CLR     NaN
# 64233   4.0  1015.6  0.0000  0.0000   NaN   CLR     NaN
# 64234   0.0  1015.1  0.0000  0.0000   NaN   FEW   500.0
# 64235   0.0  1014.3  0.0000  0.0000   NaN   CLR     NaN
# 64236   0.0  1016.4  0.0001  0.0001   NaN   CLR     NaN
#
# [64237 rows x 15 columns]

# %%
# It is often good practice to drop missing data, so let's do just that. 
input_data_nona = input_data.dropna()

# %%
input_data_nona
# Out:
#       station             valid  tmpf   tmpc  dwpf   dwpc   relh    feel  \
# 290       HSV  2023-07-01 03:53  81.0  27.22  68.0  20.00  64.69   83.76
# 299       DCU  2023-07-01 03:53  81.0  27.22  67.0  19.44  62.28   83.40
# 406       1M4  2023-07-01 04:56  79.0  26.11  75.0  23.89  87.58   79.00
# 1378      PRN  2023-07-01 16:58  91.0  32.78  73.0  22.78  55.72   99.57
# 1433      BHM  2023-07-01 17:53  96.0  35.56  73.0  22.78  47.57  106.07
# ...       ...               ...   ...    ...   ...    ...    ...     ...
# 64061     LOR  2023-07-30 22:27  78.8  26.00  71.6  22.00  78.62   78.80
# 64065     HEY  2023-07-30 22:32  80.6  27.00  71.6  22.00  74.11   84.57
# 64084     OZR  2023-07-30 22:37  77.0  25.00  71.6  22.00  83.44   77.00
# 64109     BFM  2023-07-30 22:53  80.0  26.67  73.0  22.78  79.25   84.13
# 64230     MOB  2023-07-30 23:56  82.0  27.78  72.0  22.22  71.78   86.83
#
#        sknt    mslp    p01m    p01i  gust skyc1   skyl1
# 290    24.0  1017.4  0.0001  0.0001  36.0   FEW   900.0
# 299    16.0  1017.5  0.0000  0.0000  31.0   FEW  4700.0
# 406    11.0  1017.1  0.0000  0.0000  19.0   FEW  3000.0
# 1378    5.0  1011.7  0.0000  0.0000  14.0   FEW  3700.0
# 1433   12.0  1015.5  0.0000  0.0000  17.0   BKN  4800.0
# ...     ...     ...     ...     ...   ...   ...     ...
# 64061   8.0  1014.4  0.0000  0.0000  16.0   SCT  2100.0
# 64065   6.0  1015.5  0.0000  0.0000  16.0   FEW  2000.0
# 64084   9.0  1015.9  0.0000  0.0000  18.0   SCT  3000.0
# 64109   5.0  1016.5  1.7800  0.0700  20.0   BKN  5000.0
# 64230  14.0  1016.1  0.0001  0.0001  19.0   BKN  4100.0
#
# [583 rows x 15 columns]

# %% [markdown]
# 583 rows!?! That's not enough. Remember to be careful as you're doing this...

# %%
input_data_nona = input_data.drop('gust', axis=1).dropna()

# %%
input_data_nona
# Out:
#       station             valid  tmpf   tmpc  dwpf   dwpc    relh    feel  \
# 2         HUA  2023-07-01 00:14  89.6  32.00  77.0  25.00   66.55  102.54
# 22        HUA  2023-07-01 00:25  89.6  32.00  77.0  25.00   66.55  102.54
# 46        BHM  2023-07-01 00:53  93.0  33.89  71.0  21.67   49.09  100.13
# 49        HSV  2023-07-01 00:53  89.0  31.67  78.0  25.56   70.12  103.36
# 72        HUA  2023-07-01 00:55  88.3  31.28  77.7  25.39   70.97  101.60
# ...       ...               ...   ...    ...   ...    ...     ...     ...
# 64217     SXS  2023-07-30 23:55  74.0  23.33  73.6  23.11   98.66   74.00
# 64227     HEY  2023-07-30 23:55  77.5  25.28  75.0  23.89   92.02   77.50
# 64228     LOR  2023-07-30 23:55  75.4  24.11  73.2  22.89   92.89   75.40
# 64230     MOB  2023-07-30 23:56  82.0  27.78  72.0  22.22   71.78   86.83
# 64234     SXS  2023-07-30 23:56  73.4  23.00  73.4  23.00  100.00   73.40
#
#        sknt    mslp    p01m    p01i skyc1    skyl1
# 2       5.0  1013.9  0.0000  0.0000   FEW   4700.0
# 22      5.0  1013.9  0.0000  0.0000   FEW   4700.0
# 46     10.0  1014.2  0.0000  0.0000   FEW  15000.0
# 49      3.0  1013.8  0.0000  0.0000   FEW   5500.0
# 72      4.0  1013.9  0.0001  0.0001   BKN   4400.0
# ...     ...     ...     ...     ...   ...      ...
# 64217   0.0  1014.7  0.2500  0.0100   FEW    700.0
# 64227   0.0  1014.1  0.0001  0.0001   SCT   9500.0
# 64228   3.0  1013.7  0.0001  0.0001   FEW   9000.0
# 64230  14.0  1016.1  0.0001  0.0001   BKN   4100.0
# 64234   0.0  1015.1  0.0000  0.0000   FEW    500.0
#
# [11079 rows x 14 columns]

# %% [markdown]
# See any issues here?

# %%
input_data_renamed_clouds = copy.deepcopy(input_data)
all_cloud_vals = input_data_renamed_clouds['skyc1']
all_cloud_vals.fillna('CLR')
input_data_renamed_clouds['skyc1'] = all_cloud_vals
input_data_renamed_clouds
# Out:
#       station             valid  tmpf   tmpc  dwpf   dwpc    relh    feel  \
# 0         HEY  2023-07-01 00:11  87.8  31.00  71.6  22.00   58.78   94.18
# 1         SXS  2023-07-01 00:12  87.8  31.00  71.6  22.00   58.78   94.18
# 2         HUA  2023-07-01 00:14  89.6  32.00  77.0  25.00   66.55  102.54
# 3         8A0  2023-07-01 00:15  86.0  30.00  73.4  23.00   66.15   93.45
# 4         4A6  2023-07-01 00:15   NaN    NaN   NaN    NaN     NaN     NaN
# ...       ...               ...   ...    ...   ...    ...     ...     ...
# 64232     EKY  2023-07-30 23:56  79.0  26.11  76.0  24.44   90.55   79.00
# 64233     79J  2023-07-30 23:56  76.0  24.44  73.0  22.78   90.44   76.00
# 64234     SXS  2023-07-30 23:56  73.4  23.00  73.4  23.00  100.00   73.40
# 64235     EUF  2023-07-30 23:58  79.0  26.11  75.0  23.89   87.58   79.00
# 64236     0J4  2023-07-30 23:58  78.0  25.56  72.0  22.22   81.82   78.00
#
#        sknt    mslp    p01m    p01i  gust skyc1   skyl1
# 0       0.0  1013.0  0.0000  0.0000   NaN   CLR     NaN
# 1       0.0  1013.6  0.0000  0.0000   NaN   CLR     NaN
# 2       5.0  1013.9  0.0000  0.0000   NaN   FEW  4700.0
# 3       0.0     NaN  0.0000  0.0000   NaN   CLR     NaN
# 4       NaN     NaN  0.0000  0.0000   NaN   NaN     NaN
# ...     ...     ...     ...     ...   ...   ...     ...
# 64232   0.0  1001.8  0.0000  0.0000   NaN   CLR     NaN
# 64233   4.0  1015.6  0.0000  0.0000   NaN   CLR     NaN
# 64234   0.0  1015.1  0.0000  0.0000   NaN   FEW   500.0
# 64235   0.0  1014.3  0.0000  0.0000   NaN   CLR     NaN
# 64236   0.0  1016.4  0.0001  0.0001   NaN   CLR     NaN
#
# [64237 rows x 15 columns]

# %%
input_data_nona = input_data_renamed_clouds.drop(['gust', 'skyl1', 'mslp'], axis=1).dropna()

# %%
input_data_nona
# Out:
#       station             valid  tmpf   tmpc  dwpf   dwpc    relh    feel  \
# 0         HEY  2023-07-01 00:11  87.8  31.00  71.6  22.00   58.78   94.18
# 1         SXS  2023-07-01 00:12  87.8  31.00  71.6  22.00   58.78   94.18
# 2         HUA  2023-07-01 00:14  89.6  32.00  77.0  25.00   66.55  102.54
# 3         8A0  2023-07-01 00:15  86.0  30.00  73.4  23.00   66.15   93.45
# 5         JFX  2023-07-01 00:15  91.4  33.00  78.8  26.00   66.75  107.79
# ...       ...               ...   ...    ...   ...    ...     ...     ...
# 64232     EKY  2023-07-30 23:56  79.0  26.11  76.0  24.44   90.55   79.00
# 64233     79J  2023-07-30 23:56  76.0  24.44  73.0  22.78   90.44   76.00
# 64234     SXS  2023-07-30 23:56  73.4  23.00  73.4  23.00  100.00   73.40
# 64235     EUF  2023-07-30 23:58  79.0  26.11  75.0  23.89   87.58   79.00
# 64236     0J4  2023-07-30 23:58  78.0  25.56  72.0  22.22   81.82   78.00
#
#        sknt    p01m    p01i skyc1
# 0       0.0  0.0000  0.0000   CLR
# 1       0.0  0.0000  0.0000   CLR
# 2       5.0  0.0000  0.0000   FEW
# 3       0.0  0.0000  0.0000   CLR
# 5       3.0  0.0000  0.0000   FEW
# ...     ...     ...     ...   ...
# 64232   0.0  0.0000  0.0000   CLR
# 64233   4.0  0.0000  0.0000   CLR
# 64234   0.0  0.0000  0.0000   FEW
# 64235   0.0  0.0000  0.0000   CLR
# 64236   0.0  0.0001  0.0001   CLR
#
# [61019 rows x 12 columns]

# %%
plt.scatter(input_data_nona['tmpf'], input_data_nona['feel'])
plt.xlabel("Temperature (F)")
plt.ylabel("Heat index (F)")
# Out:
# Text(0, 0.5, 'Heat index (F)')

# %%
def nws_heat_index(T, RH):
    '''
    T in fahrenheit, RH in %
    https://www.wpc.ncep.noaa.gov/html/heatindex_equation.shtml
    '''
    initial_hi =  0.5 * (T + 61.0 + ((T-68.0)*1.2) + (RH*0.094))
    if initial_hi < 80:
        return initial_hi

    adjustment_factor = 0
    if T>=80 and T<=112 and RH <13:
        adjustment_factor =  ((13-RH)/4)*np.sqrt((17-np.abs(T-95.))/17)
    
    if T>=80 and T<=87 and RH > 85:
         adjustment_factor = ((RH-85)/10) * ((87-T)/5)

    return (-42.379 + 2.04901523*T + 10.14333127*RH - .22475541*T*RH - .00683783*T*T - 
           .05481717*RH*RH + .00122874*T*T*RH + .00085282*T*RH*RH - .00000199*T*T*RH*RH) + adjustment_factor

nws_heat_index_vectorized = np.vectorize(nws_heat_index)

# %%
our_calc_hi = nws_heat_index_vectorized(input_data_nona['tmpf'], input_data_nona['relh'])

# %%
plt.scatter(our_calc_hi, input_data_nona['feel'])
plt.xlabel("Found HI Equation (F)")
plt.ylabel("IEM Reported Feels Like")
# Out:
# Text(0, 0.5, 'IEM Reported Feels Like')

# %%
plt.scatter(our_calc_hi, input_data_nona['feel'])
plt.xlabel("Found HI Equation (F)")
plt.ylabel("IEM Reported Feels Like")
plt.xlim(80, 120)
plt.ylim(80, 120)
# Out:
# (80.0, 120.0)

# %% [markdown]
# Let's try this with an ANN

# %%
from sklearn.model_selection import train_test_split

# %%
# Prepare our data first
training_data, test_validation = train_test_split(input_data_nona, test_size=0.25)
testing_data, validation_data = train_test_split(test_validation, test_size=0.5)

# %%
training_data['tmpf'].values.shape
# Out:
# (45764,)

# %%
np.sum(pd.isna(training_data['tmpf'].values))
# Out:
# 0

# %%
# Let's try adding different layers
input1 = keras.layers.Input(shape=(2, ))
input_norm = keras.layers.Normalization()(input1)


dense1 = keras.layers.Dense(128, input_dim=0, activation=None)(input_norm)
lerelu_layer = keras.layers.LeakyReLU(alpha=0.3)(dense1) 
dense2 = keras.layers.Dense(64, input_dim=0, activation=keras.activations.relu)(lerelu_layer)

output = keras.layers.Dense(1, activation=keras.activations.relu, use_bias=True)(dense2)
model = keras.models.Model(inputs=[input1], outputs=[output])
model.compile(optimizer=keras.optimizers.legacy.Adam(), loss='mean_squared_error')
model.summary()
# Out:
# 2024-03-21 08:23:45.497508: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2024-03-21 08:23:45.497533: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2024-03-21 08:23:45.497542: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2024-03-21 08:23:45.497580: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-21 08:23:45.497598: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  normalization (Normalizati  (None, 2)                 5
#  on)
#
#  dense (Dense)               (None, 128)               384
#
#  leaky_re_lu (LeakyReLU)     (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 8710 (34.03 KB)
# Trainable params: 8705 (34.00 KB)
# Non-trainable params: 5 (24.00 Byte)
# _________________________________________________________________

# %%
model.fit(training_data[['tmpf', 'relh']].values, 
           training_data['feel'].values, epochs=3, batch_size=64)
# Out:
# Epoch 1/3
# 2024-03-21 08:23:46.798271: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 716/716 [==============================] - 4s 5ms/step - loss: 57.0709
# Epoch 2/3
# 716/716 [==============================] - 3s 4ms/step - loss: 9.8103
# Epoch 3/3
# 716/716 [==============================] - 3s 4ms/step - loss: 9.6969

# %%
predicted_hi = model.predict(testing_data[['tmpf', 'relh']].values)
# Out:
# 239/239 [==============================] - 1s 2ms/step

# %%
plt.scatter(predicted_hi, testing_data['feel'])
plt.xlabel("Predicted from model (F)")
plt.ylabel("IEM Reported Feels Like")
#plt.xlim(50, 120)
#plt.ylim(50, 120)
plt.plot([50, 120], [50, 120], color='grey', ls='--')

# %%
def f(X):
    return model.predict(X).flatten()

# %%
explainer = shap.KernelExplainer(f, training_data[['tmpf', 'relh']].values[:50, :])
shap_values = explainer.shap_values(training_data[['tmpf', 'relh']].values[299, :], nsamples=500)
shap.force_plot(explainer.expected_value, shap_values, training_data[['tmpf', 'relh']].iloc[299, :])
# Out:
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 2ms/step
# <div id='iE8W5O83SGNB7FFPJ9XVP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 80.8494139099121, "outValue": 72.9303207397461, "link": "identity", "featureNames": ["tmpf", "relh"], "features": {"0": {"effect": -5.028562469482402, "value": 75.2}, "1": {"effect": -2.8905307006836054, "value": 100.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iE8W5O83SGNB7FFPJ9XVP')
#   );
# </script>

# %%
shap_values50 = explainer.shap_values(training_data[['tmpf', 'relh']].iloc[280:330, :], nsamples=500)
shap.force_plot(explainer.expected_value, shap_values50, training_data[['tmpf', 'relh']].iloc[280:330, :])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 2ms/step
# <div id='iAM0VJ7JTNLRARWKZNRJG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 80.8494139099121, "link": "identity", "featureNames": ["tmpf", "relh"], "explanations": [{"outValue": 74.71891784667969, "simIndex": 27.0, "features": {"0": {"effect": -3.090897750854495, "value": 77.0}, "1": {"effect": -3.039598312377919, "value": 100.0}}}, {"outValue": 73.40815734863281, "simIndex": 25.0, "features": {"0": {"effect": -4.786854476928674, "value": 75.6}, "1": {"effect": -2.6544020843506146, "value": 96.39}}}, {"outValue": 69.6247787475586, "simIndex": 1.0, "features": {"0": {"effect": -12.702692413330091, "value": 69.0}, "1": {"effect": 1.4780572509765832, "value": 75.66}}}, {"outValue": 69.35314178466797, "simIndex": 14.0, "features": {"0": {"effect": -8.881198806762697, "value": 71.6}, "1": {"effect": -2.6150733184814356, "value": 100.0}}}, {"outValue": 96.97988891601562, "simIndex": 41.0, "features": {"0": {"effect": 12.584510955810579, "value": 89.6}, "1": {"effect": 3.5459640502929446, "value": 70.63}}}, {"outValue": 68.95816802978516, "simIndex": 15.0, "features": {"0": {"effect": -9.325304260253901, "value": 71.2}, "1": {"effect": -2.565941619873044, "value": 99.66}}}, {"outValue": 98.82051849365234, "simIndex": 49.0, "features": {"0": {"effect": 15.19476615905765, "value": 93.2}, "1": {"effect": 2.776338424682592, "value": 52.73}}}, {"outValue": 70.2597427368164, "simIndex": 11.0, "features": {"0": {"effect": -8.01453392028808, "value": 72.5}, "1": {"effect": -2.5751372528076146, "value": 98.32}}}, {"outValue": 74.45728302001953, "simIndex": 26.0, "features": {"0": {"effect": -4.2500158691406185, "value": 76.0}, "1": {"effect": -2.1421150207519517, "value": 93.53}}}, {"outValue": 69.77265167236328, "simIndex": 12.0, "features": {"0": {"effect": -8.630354766845713, "value": 72.0}, "1": {"effect": -2.4464074707031074, "value": 96.99}}}, {"outValue": 74.54969024658203, "simIndex": 17.0, "features": {"0": {"effect": -5.197442321777331, "value": 75.2}, "1": {"effect": -1.1022813415527395, "value": 88.59}}}, {"outValue": 96.79478454589844, "simIndex": 40.0, "features": {"0": {"effect": 12.151729965209995, "value": 89.6}, "1": {"effect": 3.793640670776341, "value": 66.55}}}, {"outValue": 73.48729705810547, "simIndex": 16.0, "features": {"0": {"effect": -7.397500762939437, "value": 73.4}, "1": {"effect": 0.03538391113280426, "value": 83.21}}}, {"outValue": 98.75446319580078, "simIndex": 45.0, "features": {"0": {"effect": 14.255407638549798, "value": 92.0}, "1": {"effect": 3.649641647338882, "value": 59.71}}}, {"outValue": 70.74427032470703, "simIndex": 7.0, "features": {"0": {"effect": -7.3859870147704925, "value": 73.0}, "1": {"effect": -2.7191565704345777, "value": 100.0}}}, {"outValue": 71.14173889160156, "simIndex": 5.0, "features": {"0": {"effect": -6.958817520141594, "value": 73.4}, "1": {"effect": -2.7488574981689453, "value": 100.0}}}, {"outValue": 87.0741958618164, "simIndex": 34.0, "features": {"0": {"effect": 1.5800124359130905, "value": 80.6}, "1": {"effect": 4.644769515991214, "value": 61.58}}}, {"outValue": 71.36096954345703, "simIndex": 8.0, "features": {"0": {"effect": -7.855414962768556, "value": 73.0}, "1": {"effect": -1.633029403686514, "value": 90.32}}}, {"outValue": 81.9983139038086, "simIndex": 32.0, "features": {"0": {"effect": 0.35992034912109716, "value": 79.7}, "1": {"effect": 0.7889796447753952, "value": 81.66}}}, {"outValue": 72.9303207397461, "simIndex": 22.0, "features": {"0": {"effect": -5.028562469482402, "value": 75.2}, "1": {"effect": -2.8905307006836054, "value": 100.0}}}, {"outValue": 72.9303207397461, "simIndex": 23.0, "features": {"0": {"effect": -5.028562469482402, "value": 75.2}, "1": {"effect": -2.8905307006836054, "value": 100.0}}}, {"outValue": 73.18914031982422, "simIndex": 18.0, "features": {"0": {"effect": -5.462881927490244, "value": 75.0}, "1": {"effect": -2.1973916625976386, "value": 93.51}}}, {"outValue": 97.03346252441406, "simIndex": 43.0, "features": {"0": {"e ...
