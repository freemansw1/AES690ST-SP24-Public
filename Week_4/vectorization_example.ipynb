# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# %%
all_metars = pd.read_csv("./test_metar.txt")

# %%
all_metars
# Out:
#       station             valid      lon      lat   tmpf   dwpf    relh  \
# 0         SEM  2024-01-01 00:00 -86.9878  32.3439  42.80  35.60   75.50
# 1         DYA  2024-01-01 00:15 -87.9541  32.4638  46.40  35.60   65.83
# 2         ALX  2024-01-01 00:15 -85.9613  32.9143  43.00  35.20   73.75
# 3         4A6  2024-01-01 00:15 -86.0059  34.6887  50.00  33.80   53.54
# 4         JFX  2024-01-01 00:15 -87.3142  33.9020  39.20  35.60   86.79
# ...       ...               ...      ...      ...    ...    ...     ...
# 38996     SEM  2024-01-19 07:40 -86.9878  32.3439  50.00  50.00  100.00
# 38997     MGM  2024-01-19 07:41 -86.3940  32.3006  50.00  50.00  100.00
# 38998     LOR  2024-01-19 07:42 -85.7511  31.3558  53.60  51.80   93.60
# 38999     SXS  2024-01-19 07:42 -85.8549  31.3612  51.80  51.80  100.00
# 39000     TOI  2024-01-19 07:44 -86.0121  31.8604  53.00  50.00   89.51
#
#          drct  sknt  p01i  ... wxcodes ice_accretion_1hr ice_accretion_3hr  \
# ...

# %%
all_metars.columns
# Out:
# Index(['station', 'valid', 'lon', 'lat', 'tmpf', 'dwpf', 'relh', 'drct',
#        'sknt', 'p01i', 'alti', 'mslp', 'vsby', 'gust', 'skyc1', 'skyc2',
#        'skyc3', 'skyc4', 'skyl1', 'skyl2', 'skyl3', 'skyl4', 'wxcodes',
#        'ice_accretion_1hr', 'ice_accretion_3hr', 'ice_accretion_6hr',
#        'peak_wind_gust', 'peak_wind_drct', 'peak_wind_time', 'feel', 'metar',
#        'snowdepth'],
#       dtype='object')

# %%
all_metars['tmpf']
# Out:
# 0        42.80
# 1        46.40
# 2        43.00
# 3        50.00
# 4        39.20
#          ...
# 38996    50.00
# 38997    50.00
# 38998    53.60
# 38999    51.80
# 39000    53.00
# Name: tmpf, Length: 39001, dtype: object

# %%
all_metars['tmpf_numeric'] = pd.to_numeric(all_metars['tmpf'], errors='coerce')

# %%
all_metars['tmpf_numeric']
# Out:
# 0        42.8
# 1        46.4
# 2        43.0
# 3        50.0
# 4        39.2
#          ...
# 38996    50.0
# 38997    50.0
# 38998    53.6
# 38999    51.8
# 39000    53.0
# Name: tmpf_numeric, Length: 39001, dtype: float64

# %%
# %%time
celsius_temps = np.empty(len(all_metars))
for index, row in all_metars.iterrows():
    celsius_temps[index] = (row['tmpf_numeric']-32)*5/9
# Out:
# CPU times: user 479 ms, sys: 13.1 ms, total: 492 ms
# Wall time: 491 ms

# %%
# %%time
all_metars["tempc"] = (all_metars['tmpf_numeric']-32)*5/9
# Out:
# CPU times: user 1.32 ms, sys: 953 µs, total: 2.27 ms
# Wall time: 1.56 ms
